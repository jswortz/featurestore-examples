# %% [markdown]
# # This notebook creates an experimental design to test featurestore and executes the test

# %%
# %pip install -q doepy google-cloud-aiplatform
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# set up the featurestore client
import pandas as pd
from datetime import datetime
from dateutil.parser import parse
import datetime as datetime_class
import json
from google.cloud import bigquery
import time
from helper_fns.helpers import *


#variables change to your liking
BUCKET = "matching-engine-demo-blog"
BQ_DATASET = 'movielens'
PROJECT_ID = 'matching-engine-blog'
API_ENDPOINT = "us-central1-aiplatform.googleapis.com"  # @param {type:"string"}
FEATURESTORE_ID = "performance_testing"
REGION = 'us-central1'

n_iterations = 2
n_predictions = 100
n_workers = 1

admin_client = FeaturestoreServiceClient(client_options={"api_endpoint": API_ENDPOINT})

data_client = FeaturestoreOnlineServingServiceClient(
    client_options={"api_endpoint": API_ENDPOINT}
)

BASE_RESOURCE_PATH = admin_client.common_location_path(PROJECT_ID, REGION)

#initialize bq client for building benchmark datasets for FS
client = bigquery.Client()

# %% [markdown]
# ## Create repeat measure run function

# %%
def repeat_measure(n_iterations, n_predictions, n_workers, n_repeats=30):
    data = {'create_stats': [],
            'n_features': [],
            'n_predictions': [],
            'n_workers': [],
            'total_seconds': [],
            'n_features': []
           }
    stats = create_a_fs_run(n_iterations, n_predictions, n_workers)
    
    
    for run in range(n_repeats):
        total_time, n_features = measure_fs(n_iterations, n_predictions)
        data['create_stats'].append(stats)
        data['n_features'].append(n_features)
        data['n_predictions'].append(n_predictions)
        data['n_workers'].append(n_workers)
        data['total_seconds'].append(total_time)

    print(total_time)
    return data

# %%
from doepy import build
import pandas as pd

design_data = build.lhs(
{'Nodes':[2,10],
'N_Rows':[1, 10],
'N_Iterations':[1,10],
}, num_samples=3)

design_data = design_data[['Nodes', 'N_Rows', 'N_Iterations']].astype(int)
design_data
# Out:
#    Nodes  N_Rows  N_Iterations
# 0      7       4             3
# 1      6       9             4
# 2      2       2             9

# %%
cols = ['create_stats',
        'n_features',
        'n_predictions',
        'n_workers',
        'total_seconds']


data = pd.DataFrame([], columns=cols)

append_frame = pd.DataFrame.from_dict(repeat_run_data)
data = data.append(append_frame)
data
# Out:
#     create_stats n_features n_predictions n_workers  total_seconds
# 0    -387.904502          8             1         1       0.222427
# 1    -387.904502          8             1         1       0.182707
# 2    -387.904502          8             1         1       0.137839
# 3    -387.904502          8             1         1       0.017539
# 4    -387.904502          8             1         1       0.139842
# 5    -387.904502          8             1         1       0.184758
# 6    -387.904502          8             1         1       0.142390
# 7    -387.904502          8             1         1       0.134935
# 8    -387.904502          8             1         1       0.013840
# 9    -387.904502          8             1         1       0.163715
# 10   -387.904502          8             1         1       0.154238
# 11   -387.904502          8             1         1       0.151912
# 12   -387.904502          8             1         1       0.209299
# 13   -387.904502          8             1         1       0.119030
# 14   -387.904502          8             1         1       0.164005
# 15   -387.904502          8             1         1       0.016958
# 16   -387.904502          8             1         1       0.020545
# 17   -387.904502          8             1         1       0.134116
# 18   -387.904502          8             1         1       0.147037
# 19   -387.904502          8             1         1       0.014845
# 20   -387.904502          8             1         1       0.115256
# 21   -387.904502          8             1         1       0.166522
# 22   -387.904502          8             1         1       0.015088
# 23   -387.904502          8             1         1       0.168652
# 24   -387.904502          8             1         1       0.182784
# 25   -387.904502          8             1         1       0.158952
# 26   -387.904502          8             1         1       0.137873
# 27   -387.904502          8             1         1       0.153875
# 28   -387.904502          8             1         1       0.017023
# 29   -387.904502          8             1         1       0.014466

# %%
repeat_run_data = repeat_measure(1, 1, 1)
# Out:
# name: "projects/180938242395/locations/us-central1/featurestores/performance_testing"
#
# name: "projects/180938242395/locations/us-central1/featurestores/performance_testing/entityTypes/movies"
# etag: "AMEw9yMQBKbyLuAcUXafun0DROoZgk-iNeCohjEEwH78chbqTq0q"
#
# Ran for a total of 0:05:52.755053
# imported_entity_count: 1
# imported_feature_value_count: 7
#
# Ran for a total of: 0.2224266529083252 seconds for 1 streaming predictions
#  Per prediction seconds: 0.2224266529083252
# Ran for a total of: 0.1827068328857422 seconds for 1 streaming predictions
#  Per prediction seconds: 0.1827068328857422
# Ran for a total of: 0.13783884048461914 seconds for 1 streaming predictions
#  Per prediction seconds: 0.13783884048461914
# Ran for a total of: 0.017539262771606445 seconds for 1 streaming predictions
#  Per prediction seconds: 0.017539262771606445
# Ran for a total of: 0.13984203338623047 seconds for 1 streaming predictions
#  Per prediction seconds: 0.13984203338623047
# Ran for a total of: 0.18475842475891113 seconds for 1 streaming predictions
#  Per prediction seconds: 0.18475842475891113
# Ran for a total of: 0.14239001274108887 seconds for 1 streaming predictions
#  Per prediction seconds: 0.14239001274108887
# Ran for a total of: 0.1349349021911621 seconds for 1 streaming predictions
#  Per prediction seconds: 0.1349349021911621
# Ran for a total of: 0.0138397216796875 seconds for 1 streaming predictions
#  Per prediction seconds: 0.0138397216796875
# Ran for a total of: 0.16371536254882812 seconds for 1 streaming predictions
#  Per prediction seconds: 0.16371536254882812
# Ran for a total of: 0.15423846244812012 seconds for 1 streaming predictions
#  Per prediction seconds: 0.15423846244812012
# Ran for a total of: 0.15191245079040527 seconds for 1 streaming predictions
#  Per prediction seconds: 0.15191245079040527
# Ran for a total of: 0.20929884910583496 seconds for 1 streaming predictions
#  Per prediction seconds: 0.20929884910583496
# Ran for a total of: 0.11903047561645508 seconds for 1 streaming predictions
#  Per prediction seconds: 0.11903047561645508
# Ran for a total of: 0.16400527954101562 seconds for 1 streaming predictions
#  Per prediction seconds: 0.16400527954101562
# Ran for a total of: 0.016958236694335938 seconds for 1 streaming predictions
#  Per prediction seconds: 0.016958236694335938
# Ran for a total of: 0.020545482635498047 seconds for 1 streaming predictions
#  Per prediction seconds: 0.020545482635498047
# Ran for a total of: 0.13411641120910645 seconds for 1 streaming predictions
#  Per prediction seconds: 0.13411641120910645
# Ran for a total of: 0.14703702926635742 seconds for 1 streaming predictions
#  Per prediction seconds: 0.14703702926635742
# Ran for a total of: 0.014845132827758789 seconds for 1 streaming predictions
#  Per prediction seconds: 0.014845132827758789
# Ran for a total of: 0.11525630950927734 seconds for 1 streaming predictions
#  Per prediction seconds: 0.11525630950927734
# Ran for a total of: 0.16652154922485352 seconds for 1 streaming predictions
#  Per prediction seconds: 0.16652154922485352
# Ran for a total of: 0.01508784294128418 seconds for 1 streaming predictions
#  Per prediction seconds: 0.01508784294128418
# Ran for a total of: 0.16865229606628418 seconds for 1 streaming predictions
#  Per prediction seconds: 0.16865229606628418
# Ran for a total of: 0.1827836036682129 seconds for 1 streaming predictions
#  Per prediction seconds: 0.1827836036682129
# Ran for a total of: 0.1589517593383789 seconds for 1 streaming predictions
#  Per prediction seconds: 0.1589517593383789
# Ran for a total of: 0.13787317276000977 seconds for 1 streaming predictions
#  Per prediction seconds: 0.13787317276000977
# Ran for a total of: 0.15387511253356934 seconds for 1 streaming predictions
#  Per prediction seconds: 0.15387511253356934
# Ran for a total of: 0.017023324966430664 seconds for 1 streaming predictions
#  Per prediction seconds: 0.017023324966430664
# Ran for a total of: 0.014466285705566406 seconds for 1 streaming predictions
#  Per prediction seconds: 0.014466285705566406
# 0.014466285705566406

# %%
# run the experiment and store data

cols = ['create_stats',
        'n_features',
        'n_predictions',
        'n_workers',
        'total_seconds']


data = pd.DataFrame([], columns=cols)

for index, row in design_data.iterrows():
    print(f"Testing for following row: \n{row}")
    repeat_run_data = repeat_measure(row['N_Iterations']
                                     , row['N_Rows']
                                     , row['Nodes'], n_repeats=30)
    append_frame = pd.DataFrame.from_dict(repeat_run_data)
    data = data.append(append_frame, ignore_index=True)
    ts = datetime.now()
    data.to_csv(f'data/experiment-{ts}.csv')
    
#save to csv
ts = datetime.now()
data.to_csv(f'data/experiment-{ts}.csv')

data
# Out:
# Testing for following row:
# Nodes           7
# N_Rows          4
# N_Iterations    3
# Name: 0, dtype: int64
# Deleted featurestore 'performance_testing'.
# name: "projects/180938242395/locations/us-central1/featurestores/performance_testing"
#
# name: "projects/180938242395/locations/us-central1/featurestores/performance_testing/entityTypes/movies"
# etag: "AMEw9yO8gMqPBcdpLNJ4DSIL0_F_rCBQblDURlEmW5yGKJzUIR92"
#
# Ran for a total of 0:06:04.743344
# imported_entity_count: 4
# imported_feature_value_count: 84
#
# Ran for a total of: 0.26798510551452637 seconds for 4 streaming predictions
#  Per prediction seconds: 0.06699627637863159
# Ran for a total of: 0.2606830596923828 seconds for 4 streaming predictions
#  Per prediction seconds: 0.0651707649230957
# Ran for a total of: 0.21416187286376953 seconds for 4 streaming predictions
#  Per prediction seconds: 0.05354046821594238
# Ran for a total of: 0.2054762840270996 seconds for 4 streaming predictions
#  Per prediction seconds: 0.0513690710067749
# Ran for a total of: 0.17568588256835938 seconds for 4 streaming predictions
#  Per prediction seconds: 0.043921470642089844
# Ran for a total of: 0.17110586166381836 seconds for 4 streaming predictions
#  Per prediction seconds: 0.04277646541595459
# Ran for a total of: 0.12917876243591309 seconds for 4 streaming predictions
#  Per prediction seconds: 0.03229469060897827
# Ran for a total of: 0.15517759323120117 seconds for 4 streaming predictions
#  Per prediction seconds: 0.03879439830780029
# Ran for a total of: 0.1780087947845459 seconds for 4 streaming predictions
#  Per prediction seconds: 0.044502198696136475
# Ran for a total of: 0.17392277717590332 seconds for 4 streaming predictions
#  Per prediction seconds: 0.04348069429397583
# Ran for a total of: 0.18303632736206055 seconds for 4 streaming predictions
#  Per prediction seconds: 0.04575908184051514
# Ran for a total of: 0.18401646614074707 seconds for 4 streaming predictions
#  Per prediction seconds: 0.04600411653518677
# Ran for a total of: 0.19627594947814941 seconds for 4 streaming predictions
#  Per prediction seconds: 0.049068987369537354
# Ran for a total of: 0.18961691856384277 seconds for 4 streaming predictions
#  Per prediction seconds: 0.04740422964096069
# Ran for a total of: 0.2107241153717041 seconds for 4 streaming predictions
#  Per prediction seconds: 0.052681028842926025
# Ran for a total of: 0.24074578285217285 seconds for 4 streaming predictions
#  Per prediction seconds: 0.06018644571304321
# Ran for a total of: 0.15560340881347656 seconds for 4 streaming predictions
#  Per prediction seconds: 0.03890085220336914
# Ran for a total of: 0.19163942337036133 seconds for 4 streaming predictions
#  Per prediction seconds: 0.04790985584259033
# Ran for a total of: 0.1847851276397705 seconds for 4 streaming predictions
#  Per prediction seconds: 0.04619628190994263
# Ran for a total of: 0.014281749725341797 seconds for 4 streaming predictions
#  Per prediction seconds: 0.0035704374313354492
# Ran for a total of: 0.17699098587036133 seconds for 4 streaming predictions
#  Per prediction seconds: 0.04424774646759033
# Ran for a total of: 0.020250558853149414 seconds for 4 streaming predictions
#  Per prediction seconds: 0.0050626397132873535
# Ran for a total of: 0.21155905723571777 seconds for 4 streaming predictions
#  Per prediction seconds: 0.05288976430892944
# Ran for a total of: 0.014825582504272461 seconds for 4 streaming predictions
#  Per prediction seconds: 0.0037063956260681152
# Ran for a total of: 0.14640593528747559 seconds for 4 streaming predictions
#  Per prediction seconds: 0.036601483821868896
# Ran for a total of: 0.015199899673461914 seconds for 4 streaming predictions
#  Per prediction seconds: 0.0037999749183654785
# Ran for a total of: 0.01413583755493164 seconds for 4 streaming predictions
#  Per prediction seconds: 0.00353395938873291
# Ran for a total of: 0.01921224594116211 seconds for 4 streaming predictions
#  Per prediction seconds: 0.004803061485290527
# Ran for a total of: 0.019901275634765625 seconds for 4 streaming predictions
#  Per prediction seconds: 0.004975318908691406
# Ran for a total of: 0.0149078369140625 seconds for 4 streaming predictions
#  Per prediction seconds: 0.003726959228515625
# 0.0149078369140625
# Testing for following row:
# Nodes           6
# N_Rows          9
# N_Iterations    4
# Name: 1, dtype: int64
# Deleted featurestore 'performance_testing'.
# name: "projects/180938242395/locations/us-central1/featurestores/performance_testing"
#
# name: "projects/180938242395/locations/us-central1/featurestores/performance_testing/entityTypes/movies"
# etag: "AMEw9yNO3whGfLhJvsHYCXNlOWr_CRdJcLUqc-j7_Wwb2NGe7xzY"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_334/596934387.py in <module>
#      14     repeat_run_data = repeat_measure(row['N_Iterations']
#      15                                      , row['N_Rows']
# ---> 16                                      , row['Nodes'], n_repeats=30)
#      17     append_frame = pd.DataFrame(repeat_run_data, columns=cols)
#      18     data.append(append_frame, ignore_index=True)
#
# /tmp/ipykernel_334/3952727352.py in repeat_measure(n_iterations, n_predictions, n_workers, n_repeats)
#       7             'n_features': []
#       8            }
# ----> 9     stats = create_a_fs_run(n_iterations, n_predictions, n_workers)
#      10
#      11
#
# ~/matching-engine-demo/Feature_Store_Examples/helper_fns/helpers.py in create_a_fs_run(n_iterations, n_predictions, n_workers)
#     259     #update featurestore two itertions
#     260     ingestion_lro = load_fs(n_iterations, n_workers=n_workers)
# --> 261     poll_loading_data(ingestion_lro)
#     262     load_time = start_time - time.time()
#     263     lro_creation_metrics = print(ingestion_lro.result())
#
# ~/matching-engine-demo/Feature_Store_Examples/helper_fns/helpers.py in poll_loading_data(ingestion_lro)
#     205     mins = 0
#     206     while True: #polling to keep the session alive every x minutes
# --> 207         if ingestion_lro.done():
#     208             break
#     209         #print(f"Running for {mins} minutes")
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/operation.py in done(self, retry)
#     168             bool: True if the operation is complete, False otherwise.
#     169         """
# --> 170         self._refresh_and_update(retry)
#     171         return self._operation.done
#     172
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/operation.py in _refresh_and_update(self, retry)
#     156         # RPC as it will not change once done.
#     157         if not self._operation.done:
# --> 158             self._operation = self._refresh(retry=retry)
#     159             self._set_result_from_operation()
#     160
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/operations_v1/operations_client.py in get_operation(self, name, retry, timeout, metadata)
#     141
#     142         return self._get_operation(
# --> 143             request, retry=retry, timeout=timeout, metadata=metadata
#     144         )
#     145
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/gapic_v1/method.py in __call__(self, *args, **kwargs)
#     143             kwargs["metadata"] = metadata
#     144
# --> 145         return wrapped_func(*args, **kwargs)
#     146
#     147
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     289                 sleep_generator,
#     290                 self._deadline,
# --> 291                 on_error=on_error,
#     292             )
#     293
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     218             "Retrying due to {}, sleeping {:.1f}s ...".format(last_exc, sleep)
#     219         )
# --> 220         time.sleep(sleep)
#     221
#     222     raise ValueError("Sleep generator stopped yielding sleep values.")
#
# KeyboardInterrupt:

# %%
# !gsutil cp f'experiment-$ts.csv' gs://$BUCKET/benchmarking_data
